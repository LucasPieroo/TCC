# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# %%
url = "https://www.skoob.com.br/estante/livros/1/2775810/page:1"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html xmlns="//www.w3.org/1999/xhtml">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# books: http://ogp.me/ns/books#">
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/> <title>Login</title>
# <meta content="pt-br" name="language"/>
# <meta content="h_F9-djAws40JfpX_W4juzsPjd9YZ2v-s0YvOG-D388" name="google-site-verification"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="app-id=904670263" name="apple-itunes-app"/>
# <meta content="app-id=com.gaudium.skoob" name="google-play-app"/>
# <meta content="none" name="msapplication-config"/>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-KT8Z35D20V"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#   gtag('config', 'G-KT8Z35D20V');
# </script>
# <script type="text/javascript">
#   var googletag = googletag || {};
# ...

# %% [markdown]
# # Coleta de partidas

# %%
import requests
import csv

user_id = '288784'#'9472929' # 
shelf_id = '0'
page = '1'
limit = '2000'

url = f'https://www.skoob.com.br/v1/bookcase/books/{user_id}/shelf_id:{shelf_id}/page:{page}/limit:{limit}'
resp = requests.get(url=url)
books = resp.json()['response']

for book in books:
    data_leitura = book['dt_leitura']
    paginas = book['paginas']
    nota = book['ranking']
    edicao = book['edicao']
    titulo = edicao['titulo']
    ano = edicao['ano'] 
    autor = edicao['autor']
    if (paginas == ""): paginas = edicao['paginas']

    dict_book = {'data_leitura': data_leitura, 'paginas': paginas, 'nota': nota, 'titulo': titulo, 'ano': ano, 'autor': autor}

    print(dict_book)
# Out:
# {'data_leitura': '', 'paginas': 528, 'nota': 0, 'titulo': 'Três', 'ano': 2023, 'autor': 'Valérie Perrin'}
# {'data_leitura': '', 'paginas': 336, 'nota': 0, 'titulo': 'A filha da rainha sereia', 'ano': 2023, 'autor': 'Tricia Levenseller'}
# {'data_leitura': '', 'paginas': 496, 'nota': 0, 'titulo': 'Desejo', 'ano': 2021, 'autor': 'Tracy Wolff'}
# {'data_leitura': '', 'paginas': 272, 'nota': 0, 'titulo': 'A mágica mortal', 'ano': 2023, 'autor': 'Raphael Montes'}
# {'data_leitura': '', 'paginas': 272, 'nota': 0, 'titulo': 'Bem-vindos à livraria  Hyunam-Dong', 'ano': 2023, 'autor': 'Hwang Bo-Reum'}
# {'data_leitura': '', 'paginas': 304, 'nota': 5, 'titulo': 'A mulher em mim', 'ano': 2023, 'autor': 'Britney Spears'}
# {'data_leitura': '2023-10-28 22:10:03', 'paginas': 336, 'nota': 4, 'titulo': 'Amor em Roma', 'ano': 2023, 'autor': 'Sarah Adams'}
# {'data_leitura': '', 'paginas': 416, 'nota': 0, 'titulo': 'Parem os relógios', 'ano': 2023, 'autor': 'Kristan Higgins'}
# ...

# %%
len(books)
# Out:
# 1164

# %%
books[126]
# Out:
# {'id': 210742891,
#  'livro_id': 11647619,
#  'ranking': 5,
#  'tipo': 1,
#  'favorito': 1,
#  'desejado': 0,
#  'troco': 0,
#  'tenho': 0,
#  'emprestei': 0,
#  'paginas': 528,
#  'dt_resenha': '2023-06-04 14:24:55',
#  'paginas_lidas': 0,
#  'dt_leitura': '2023-06-04 14:06:49',
#  'meta': 0,
#  'spoiler': 0,
#  'media': 0,
#  'edicao': {'id': 11686374,
#   'livro_id': 11647619,
#   'titulo': 'Pachinko',
#   'nome_portugues': 'Pachinko',
#   'subtitulo': '',
#   'subtitulo_portugues': '',
#   'idioma': '',
#   'mes': '',
#   'ano': 2020,
#   'volume': '',
#   'serie': '',
#   'autor': 'Min Jin Lee',
#   'isbn': 0,
#   'paginas': 528,
#   'edicao': 0,
#   'editora': 'Intrínseca',
# ...

# %%
books[27]
# Out:
# {'id': 225711992,
#  'livro_id': 720603,
#  'ranking': 0,
#  'tipo': 3,
#  'favorito': 0,
#  'desejado': 0,
#  'troco': 0,
#  'tenho': 0,
#  'emprestei': 0,
#  'paginas': '',
#  'dt_resenha': '',
#  'paginas_lidas': 0,
#  'dt_leitura': '',
#  'meta': 0,
#  'spoiler': 0,
#  'media': 0,
#  'edicao': {'id': 722437,
#   'livro_id': 720603,
#   'titulo': 'Um Trono Negro',
#   'nome_portugues': 'Um Trono Negro',
#   'subtitulo': '',
#   'subtitulo_portugues': '',
#   'idioma': '',
#   'mes': '',
#   'ano': 2017,
#   'volume': '',
#   'serie': '',
#   'autor': 'Kendare Blake',
#   'isbn': 0,
#   'paginas': 336,
#   'edicao': 0,
#   'editora': 'Globo Alt',
# ...
